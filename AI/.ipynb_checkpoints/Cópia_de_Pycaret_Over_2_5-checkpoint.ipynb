# %% [markdown]
# # @FutPythonTrader

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
# from google.colab import data_table
# data_table.enable_dataframe_formatter()
import warnings
warnings.filterwarnings('ignore')

def dia():
    from datetime import date, timedelta
    dia = date.today() - timedelta(0)
    return dia

def drop_reset_index(df):
    df = df.dropna()
    df = df.reset_index(drop=True)
    df.index += 1
    return df

def grafico(df, nome):
    df = df.reset_index(drop=True)
    df.index += 1
    df['Profit_acu'] = df.Profit.cumsum()
    profit = round(df.Profit_acu.tail(1).item(),2)
    ROI = round((df.Profit_acu.tail(1)/len(df)*100).item(),2)
    df.Profit_acu.plot(title=nome, xlabel='Entradas', ylabel='Stakes')
    print("Profit:",profit,"stakes em", len(df),"jogos")
    print("ROI:",ROI,"%")

# %% [markdown]
# # Pycaret

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\thiag\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: jinja2>=1.2 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.6.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: cloudpickle in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: tbats>=1.1.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: xxhash in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: numpy<1.25,>=1.21 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: scipy<2.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: numba>=0.55.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.0.9)
# Requirement already satisfied: sktime>=0.16.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.17.1)
# Requirement already satisfied: schemdraw>=0.14 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.16)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (3.3.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (6.5.0)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\thiag\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\thiag\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in c:\users\thiag\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\thiag\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: matplotlib-inline in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: backcall in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: colorama in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: decorator in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: pickleshare in c:\users\thiag\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\thiag\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\thiag\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: wheel in c:\users\thiag\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: jupyter_core in c:\users\thiag\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\thiag\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\thiag\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\thiag\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thiag\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in c:\users\thiag\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.9.3)
# Requirement already satisfied: trace-updater>=0.0.8 in c:\users\thiag\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in c:\users\thiag\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\thiag\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.8.10)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\thiag\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in c:\users\thiag\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in c:\users\thiag\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thiag\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\thiag\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thiag\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\thiag\anaconda3\lib\site-packages (from sktime>=0.16.1->pycaret) (1.2.13)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\thiag\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\thiag\anaconda3\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\thiag\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\thiag\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\thiag\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\thiag\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\thiag\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\thiag\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\thiag\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\thiag\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\thiag\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: retrying in c:\users\thiag\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\thiag\anaconda3\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\thiag\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\thiag\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in c:\users\thiag\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: click>=5.1 in c:\users\thiag\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\thiag\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\thiag\anaconda3\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: entrypoints in c:\users\thiag\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: prometheus-client in c:\users\thiag\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\thiag\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\thiag\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\thiag\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\thiag\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: bleach in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: testpath in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\thiag\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\thiag\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\thiag\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\thiag\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\thiag\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\thiag\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\thiag\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
from pycaret.classification import *

# %% [markdown]
# # Base de Dados e Jogos do Dia

# %%
base = pd.read_csv("https://github.com/futpythontrader/YouTube/blob/main/Base_de_Dados/futpythontraderpunter.csv?raw=true")
base["Date"] = pd.to_datetime(base["Date"])
base['Date'] = base['Date'].dt.date
base = base.sort_values('Date')
base = base[['Date','League','Season','Home','Away','FT_Goals_H','FT_Goals_A','FT_Odd_H','FT_Odd_D','FT_Odd_A','FT_Odd_Over25','FT_Odd_Under25','FT_Odd_BTTS_Yes','FT_Odd_BTTS_No']]

# %%
################################################################################
# Probabilidades
################################################################################
base['p_H'] = 1 / base.FT_Odd_H
base['p_D'] = 1 / base.FT_Odd_D
base['p_A'] = 1 / base.FT_Odd_A
base['p_Over'] = 1 / base.FT_Odd_Over25
base['p_Under'] = 1 / base.FT_Odd_Under25
################################################################################

################################################################################
# CV das Odds do Match Odds
################################################################################
base['CV_HDA'] = base[['p_H','p_D','p_A']].std(ddof=0, axis=1) / base[['p_H','p_D','p_A']].mean(axis=1)
################################################################################

################################################################################
# Valor do Gol
################################################################################
base['VG_H'] = base.FT_Goals_H * base.p_A
base['VG_A'] = base.FT_Goals_A * base.p_H
base['Media_VG_H'] = base.groupby('Home')['VG_H'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_VG_A'] = base.groupby('Away')['VG_A'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_VG_H'] = base.groupby('Home')['Media_VG_H'].shift(1)
base['Media_VG_A'] = base.groupby('Away')['Media_VG_A'].shift(1)
base['DP_VG_H'] = base.groupby('Home')['VG_H'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_VG_A'] = base.groupby('Away')['VG_A'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_VG_H'] = base.groupby('Home')['DP_VG_H'].shift(1)
base['DP_VG_A'] = base.groupby('Away')['DP_VG_A'].shift(1)
base['CV_VG_H'] = base['DP_VG_H'] / base['Media_VG_H']
base['CV_VG_A'] = base['DP_VG_A'] / base['Media_VG_A']
################################################################################

################################################################################
# Custo do Gol
################################################################################
base['CG_H'] = base['p_H'] / base['FT_Goals_H']
base['CG_A'] = base['p_A'] / base['FT_Goals_A']
base['Media_CG_H'] = base.groupby('Home')['CG_H'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_CG_A'] = base.groupby('Away')['CG_A'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_CG_H'] = base.groupby('Home')['Media_CG_H'].shift(1)
base['Media_CG_A'] = base.groupby('Away')['Media_CG_A'].shift(1)
base['DP_CG_H'] = base.groupby('Home')['CG_H'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_CG_A'] = base.groupby('Away')['CG_A'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_CG_H'] = base.groupby('Home')['DP_CG_H'].shift(1)
base['DP_CG_A'] = base.groupby('Away')['DP_CG_A'].shift(1)
base['CV_CG_H'] = base['DP_CG_H'] / base['Media_CG_H']
base['CV_CG_A'] = base['DP_CG_A'] / base['Media_CG_A']
################################################################################

base = base.drop(['VG_H', 'VG_A', 'CG_H', 'CG_A'], axis=1)

base.replace(np.inf, 1, inplace=True)
base.dropna(inplace=True)
base.reset_index(inplace=True, drop=True)
base.index = base.index.set_names(['Nº'])
base = base.rename(index=lambda x: x + 1)

# %%
ligas = base.sort_values(['League'])
ligas = ligas['League'].unique()
ligas
# Out:
# array(['ARGENTINA - LIGA PROFESIONAL', 'ARMENIA - PREMIER LEAGUE',
#        'AUSTRALIA - A-LEAGUE', 'AUSTRIA - 2. LIGA',
#        'AUSTRIA - BUNDESLIGA', 'AZERBAIJAN - PREMIER LEAGUE',
#        'BAHRAIN - PREMIER LEAGUE', 'BELGIUM - CHALLENGER PRO LEAGUE',
#        'BELGIUM - JUPILER PRO LEAGUE', 'BOLIVIA - DIVISION PROFESIONAL',
#        'BOSNIA AND HERZEGOVINA - PREMIER LEAGUE', 'BRAZIL - SERIE A',
#        'BRAZIL - SERIE B', 'BRAZIL - SERIE C', 'BRAZIL - SERIE D',
#        'BULGARIA - PARVA LIGA', 'CHILE - PRIMERA DIVISION',
#        'CHINA - SUPER LEAGUE', 'COLOMBIA - PRIMERA A', 'CROATIA - HNL',
#        'CROATIA - PRVA NL', 'CYPRUS - FIRST DIVISION',
#        'CZECH REPUBLIC - 1. LIGA', 'DENMARK - 1ST DIVISION',
#        'DENMARK - SUPERLIGA', 'ECUADOR - LIGA PRO',
#        'EGYPT - PREMIER LEAGUE', 'ENGLAND - CHAMPIONSHIP',
#        'ENGLAND - LEAGUE ONE', 'ENGLAND - LEAGUE TWO',
#        'ENGLAND - NATIONAL LEAGUE', 'ENGLAND - PREMIER LEAGUE',
#        'ESTONIA - MEISTRILIIGA', 'FINLAND - VEIKKAUSLIIGA',
#        'FRANCE - LIGUE 1', 'FRANCE - LIGUE 2', 'FRANCE - NATIONAL',
#        'GERMANY - 2. BUNDESLIGA', 'GERMANY - 3. LIGA',
#        'GERMANY - BUNDESLIGA', 'GREECE - SUPER LEAGUE',
#        'HUNGARY - OTP BANK LIGA', 'ICELAND - BESTA-DEILD KARLA',
#        'INDIA - ISL', 'IRELAND - PREMIER DIVISION',
#        "ISRAEL - LIGAT HA'AL", 'ITALY - SERIE A', 'ITALY - SERIE B',
#        'JAPAN - J1 LEAGUE', 'JAPAN - J2 LEAGUE', 'LITHUANIA - A LYGA',
#        'MALTA - PREMIER LEAGUE', 'MEXICO - LIGA MX',
#        'MONTENEGRO - PRVA CRNOGORSKA LIGA',
#        'NETHERLANDS - EERSTE DIVISIE', 'NETHERLANDS - EREDIVISIE',
#        'NORTHERN IRELAND - NIFL PREMIERSHIP', 'NORWAY - ELITESERIEN',
#        'NORWAY - OBOS-LIGAEN', 'PARAGUAY - PRIMERA DIVISION',
#        'PERU - LIGA 1', 'POLAND - EKSTRAKLASA',
#        'PORTUGAL - LIGA PORTUGAL', 'PORTUGAL - LIGA PORTUGAL 2',
#        'ROMANIA - LIGA 1', 'ROMANIA - LIGA 2', 'RUSSIA - PREMIER LEAGUE',
#        'SCOTLAND - CHAMPIONSHIP', 'SCOTLAND - LEAGUE ONE',
#        'SCOTLAND - LEAGUE TWO', 'SCOTLAND - PREMIERSHIP',
#        'SERBIA - SUPER LIGA', 'SLOVAKIA - FORTUNA LIGA',
#        'SLOVENIA - PRVA LIGA', 'SOUTH AFRICA - PREMIER LEAGUE',
#        'SOUTH KOREA - K LEAGUE 1', 'SOUTH KOREA - K LEAGUE 2',
#        'SPAIN - LALIGA', 'SPAIN - LALIGA2', 'SWEDEN - ALLSVENSKAN',
#        'SWEDEN - SUPERETTAN', 'SWITZERLAND - CHALLENGE LEAGUE',
#        'SWITZERLAND - SUPER LEAGUE', 'THAILAND - THAI LEAGUE 1',
#        'TURKEY - 1. LIG', 'TURKEY - SUPER LIG',
#        'UKRAINE - PREMIER LEAGUE', 'URUGUAY - PRIMERA DIVISION',
#        'USA - MLS', 'USA - USL CHAMPIONSHIP',
#        'VENEZUELA - PRIMERA DIVISION', 'WALES - CYMRU PREMIER'],
#       dtype=object)

# %%
liga = 'ARGENTINA - LIGA PROFESIONAL'

# %%
flt = base.League == liga
df = base[flt]
df = drop_reset_index(df)

# %%
df
# Out:
#            Date                        League Season               Home  \
# 1    2021-08-07  ARGENTINA - LIGA PROFESIONAL   2021         Godoy Cruz
# 2    2021-08-09  ARGENTINA - LIGA PROFESIONAL   2021    Central Cordoba
# 3    2021-08-14  ARGENTINA - LIGA PROFESIONAL   2021     Argentinos Jrs
# 4    2021-08-14  ARGENTINA - LIGA PROFESIONAL   2021    Rosario Central
# 5    2021-08-22  ARGENTINA - LIGA PROFESIONAL   2021  Union de Santa Fe
# ..          ...                           ...    ...                ...
# 691  2023-07-01  ARGENTINA - LIGA PROFESIONAL   2023        San Lorenzo
# 692  2023-07-01  ARGENTINA - LIGA PROFESIONAL   2023   Estudiantes L.P.
# 693  2023-07-02  ARGENTINA - LIGA PROFESIONAL   2023     Colon Santa Fe
# 694  2023-07-05  ARGENTINA - LIGA PROFESIONAL   2023        River Plate
# 695  2023-07-06  ARGENTINA - LIGA PROFESIONAL   2023    Arsenal Sarandi
#
#                    Away  FT_Goals_H  FT_Goals_A  FT_Odd_H  FT_Odd_D  FT_Odd_A  \
# 1           River Plate           2           1      5.00      3.80      1.65
# 2      Estudiantes L.P.           1           2      3.60      3.00      2.20
# 3              Banfield           2           0      2.20      3.10      3.60
# 4         Independiente           1           2      4.75      3.40      1.80
# 5      Talleres Cordoba           1           2      2.70      2.87      2.70
# ..                  ...         ...         ...       ...       ...       ...
# 691     Rosario Central           1           0      1.75      3.10      5.75
# 692     Central Cordoba           1           1      1.57      3.80      6.50
# 693         Racing Club           0           4      2.70      3.10      2.88
# 694      Colon Santa Fe           2           0      1.25      6.00     13.00
# 695  Defensa y Justicia           1           2      3.30      3.25      2.25
#
#      ...   DP_VG_H   DP_VG_A   CV_VG_H   CV_VG_A  Media_CG_H  Media_CG_A  \
# 1    ...  0.141026  0.602804  0.268293  0.707295    0.303419    0.151734
# 2    ...  0.241497  0.087500  0.420118  0.122807    0.275641    0.183005
# 3    ...  0.017857  0.026555  0.066667  0.068460    0.477273    0.340902
# 4    ...  0.099206  0.079082  0.263158  0.240310    0.390961    0.430626
# 5    ...  0.501390  0.112453  0.913332  0.261127    0.208993    0.331341
# ..   ...       ...       ...       ...       ...         ...         ...
# 691  ...  0.256479  0.511853  0.998052  1.239256    0.325877    0.113095
# 692  ...  0.308736  0.458986  0.813265  0.821755    0.325506    0.140046
# 693  ...  0.274800  0.480299  0.653854  0.826722    0.286565    0.283909
# 694  ...  0.281889  0.536936  0.825194  1.235349    0.364690    0.114899
# 695  ...  0.158250  0.537320  0.170095  1.376423    0.141667    0.135976
#
#       DP_CG_H   DP_CG_A   CV_CG_H   CV_CG_A
# 1    0.081197  0.052964  0.267606  0.349057
# 2    0.108974  0.027966  0.395349  0.152815
# 3    0.022727  0.030676  0.047619  0.089984
# 4    0.096844  0.082194  0.247706  0.190871
# 5    0.103507  0.079271  0.495268  0.239242
# ..        ...       ...       ...       ...
# 691  0.132923  0.029762  0.407894  0.263158
# 692  0.136293  0.012784  0.418712  0.091284
# 693  0.091786  0.155742  0.320296  0.548561
# 694  0.193376  0.023990  0.530247  0.208791
# 695  0.025644  0.037937  0.181014  0.278997
#
# [695 rows x 32 columns]

# %%
df.columns.to_list()
# Out:
# ['Date',
#  'League',
#  'Season',
#  'Home',
#  'Away',
#  'FT_Goals_H',
#  'FT_Goals_A',
#  'FT_Odd_H',
#  'FT_Odd_D',
#  'FT_Odd_A',
#  'FT_Odd_Over25',
#  'FT_Odd_Under25',
#  'FT_Odd_BTTS_Yes',
#  'FT_Odd_BTTS_No',
#  'p_H',
#  'p_D',
#  'p_A',
#  'p_Over',
#  'p_Under',
#  'CV_HDA',
#  'Media_VG_H',
#  'Media_VG_A',
#  'DP_VG_H',
#  'DP_VG_A',
#  'CV_VG_H',
#  'CV_VG_A',
#  'Media_CG_H',
#  'Media_CG_A',
#  'DP_CG_H',
#  'DP_CG_A',
#  'CV_CG_H',
#  'CV_CG_A']

# %% [markdown]
# # Criação do Modelo no Pycaret

# %%
# Over 2.5
df.loc[((df['FT_Goals_H'] + df['FT_Goals_A']) > 2), 'Over25'] = 1
df.loc[((df['FT_Goals_H'] + df['FT_Goals_A']) < 3), 'Over25'] = 0

# %%
features = ['FT_Odd_H','FT_Odd_D','FT_Odd_A','FT_Odd_Over25','FT_Odd_Under25','FT_Odd_BTTS_Yes','FT_Odd_BTTS_No','CV_HDA',
            'Media_VG_H','Media_VG_A','DP_VG_H','DP_VG_A','CV_VG_H','CV_VG_A',
            'Media_CG_H','Media_CG_A','DP_CG_H','DP_CG_A','CV_CG_H','CV_CG_A']

label = 'Over25'

# %%
# Configurando o ambiente PyCaret
exp_clf = setup(data = df[features], target = df[label])
# Out:
# <style type="text/css">
# #T_0bfb6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0bfb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bfb6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0bfb6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bfb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bfb6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0bfb6_row0_col1" class="data row0 col1" >2376</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0bfb6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0bfb6_row1_col1" class="data row1 col1" >Over25</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0bfb6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0bfb6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0bfb6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0bfb6_row3_col1" class="data row3 col1" >(695, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0bfb6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0bfb6_row4_col1" class="data row4 col1" >(695, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0bfb6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0bfb6_row5_col1" class="data row5 col1" >(486, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0bfb6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0bfb6_row6_col1" class="data row6 col1" >(209, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0bfb6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0bfb6_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0bfb6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_0bfb6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0bfb6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_0bfb6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0bfb6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_0bfb6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0bfb6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_0bfb6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0bfb6_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_0bfb6_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0bfb6_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_0bfb6_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0bfb6_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_0bfb6_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0bfb6_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_0bfb6_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0bfb6_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_0bfb6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0bfb6_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_0bfb6_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0bfb6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0bfb6_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_0bfb6_row18_col1" class="data row18 col1" >2903</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Comparando diferentes modelos de classificação
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             13:30:52
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
# Treinando o melhor modelo com os dados de treino
final_model = finalize_model(best_model)

# %%
# Fazendo previsões com os dados de teste
predictions = predict_model(final_model)

# %% [markdown]
# # Resultados

# %%
flt = predictions.prediction_label == 1
Over = predictions[flt]
Over.loc[(Over['Over25'] == 1), 'Profit'] = Over['FT_Odd_Over25']-1
Over.loc[(Over['Over25'] == 0), 'Profit'] = -1
grafico(Over,'Over 2.5 Pycaret')

# %% [markdown]
# # Salvando o Modelo

# %%
# Salvando o modelo treinado
save_model(final_model, 'Pycaret '+liga)

# %% [markdown]
# # Importando os Jogos do Dia

# %%
jogos_do_dia = pd.read_csv('https://github.com/futpythontrader/YouTube/blob/main/Jogos_do_Dia_FlashScore/'+str(dia())+'_Jogos_do_Dia_FlashScore.csv?raw=true')
jogos_do_dia = jogos_do_dia[['League','Round','Date','Time','Home','Away','FT_Odd_H','FT_Odd_D','FT_Odd_A','FT_Odd_Over25','FT_Odd_Under25','FT_Odd_BTTS_Yes','FT_Odd_BTTS_No']]
Jogos_do_Dia = drop_reset_index(jogos_do_dia)
Jogos_do_Dia

# %%
base = pd.read_csv("https://github.com/futpythontrader/YouTube/blob/main/Base_de_Dados/futpythontraderpunter.csv?raw=true")
base["Date"] = pd.to_datetime(base["Date"])
base['Date'] = base['Date'].dt.date
base = base.sort_values('Date')
base = base[['Date','League','Season','Home','Away','FT_Goals_H','FT_Goals_A','FT_Odd_H','FT_Odd_D','FT_Odd_A','FT_Odd_Over25','FT_Odd_Under25','FT_Odd_BTTS_Yes','FT_Odd_BTTS_No']]

# %%
################################################################################
# Probabilidades
################################################################################
base['p_H'] = 1 / base.FT_Odd_H
base['p_D'] = 1 / base.FT_Odd_D
base['p_A'] = 1 / base.FT_Odd_A
base['p_Over'] = 1 / base.FT_Odd_Over25
base['p_Under'] = 1 / base.FT_Odd_Under25
################################################################################

################################################################################
# CV das Odds do Match Odds
################################################################################
base['CV_HDA'] = base[['p_H','p_D','p_A']].std(ddof=0, axis=1) / base[['p_H','p_D','p_A']].mean(axis=1)
################################################################################

################################################################################
# Valor do Gol
################################################################################
base['VG_H'] = base.FT_Goals_H * base.p_A
base['VG_A'] = base.FT_Goals_A * base.p_H
base['Media_VG_H'] = base.groupby('Home')['VG_H'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_VG_A'] = base.groupby('Away')['VG_A'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['DP_VG_H'] = base.groupby('Home')['VG_H'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_VG_A'] = base.groupby('Away')['VG_A'].rolling(window=5, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['CV_VG_H'] = base['DP_VG_H'] / base['Media_VG_H']
base['CV_VG_A'] = base['DP_VG_A'] / base['Media_VG_A']
################################################################################

################################################################################
# Custo do Gol
################################################################################
base['CG_H'] = base['p_H'] / base['FT_Goals_H']
base['CG_A'] = base['p_A'] / base['FT_Goals_A']
base['CG_H'] = base['CG_H'].replace([np.inf, -np.inf, 0], 1)
base['CG_A'] = base['CG_A'].replace([np.inf, -np.inf, 0], 1)
base['Media_CG_H'] = base.groupby('Home')['CG_H'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['Media_CG_A'] = base.groupby('Away')['CG_A'].rolling(window=5, min_periods=2).mean().reset_index(0,drop=True)
base['DP_CG_H'] = base.groupby('Home')['CG_H'].rolling(window=11, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['DP_CG_A'] = base.groupby('Away')['CG_A'].rolling(window=11, min_periods=2).std(ddof=0).reset_index(0,drop=True)
base['CV_CG_H'] = base['DP_CG_H'] / base['Media_CG_H']
base['CV_CG_A'] = base['DP_CG_A'] / base['Media_CG_A']
################################################################################

base = base.drop(['VG_H', 'VG_A', 'CG_H', 'CG_A'], axis=1)

base.replace(np.inf, 1, inplace=True)
base.dropna(inplace=True)
base.reset_index(inplace=True, drop=True)
base.index = base.index.set_names(['Nº'])
base = base.rename(index=lambda x: x + 1)

base_H = base[['Home','Media_VG_H','DP_VG_H','CV_VG_H','Media_CG_H','DP_CG_H','CV_CG_H']]

base_A = base[['Away','Media_VG_A','DP_VG_A','CV_VG_A','Media_CG_A','DP_CG_A','CV_CG_A']]

# %%
lista=[]

for a,b,c,d,e,f,g,h,i,j,k,l in zip(Jogos_do_Dia.League,
                                   Jogos_do_Dia.Date,
                                   Jogos_do_Dia.Time,
                                   Jogos_do_Dia.Home,
                                   Jogos_do_Dia.Away,
                                   Jogos_do_Dia.FT_Odd_H,
                                   Jogos_do_Dia.FT_Odd_D,
                                   Jogos_do_Dia.FT_Odd_A,
                                   Jogos_do_Dia.FT_Odd_Over25,
                                   Jogos_do_Dia.FT_Odd_Under25,
                                   Jogos_do_Dia.FT_Odd_BTTS_Yes,
                                   Jogos_do_Dia.FT_Odd_BTTS_No):
        League = a
        Date = b
        Time = c
        home = d
        away = e
        FT_Odd_H = f
        FT_Odd_D = g
        FT_Odd_A = h
        FT_Odd_Over25 = i
        FT_Odd_Under25 = j
        FT_Odd_BTTS_Yes = k
        FT_Odd_BTTS_No = l

        df1 = base_H[base_H.Home == home].tail(1)

        df2 = base_A[base_A.Away == away].tail(1)

        jogo = {}

        jogo["League"] = League
        jogo["Date"] = Date
        jogo["Time"] = Time
        jogo["Home"] = home
        jogo["Away"] = away
        jogo["FT_Odd_H"] = FT_Odd_H
        jogo["FT_Odd_D"] = FT_Odd_D
        jogo["FT_Odd_A"] = FT_Odd_A
        jogo["FT_Odd_Over25"] = FT_Odd_Over25
        jogo["FT_Odd_Under25"] = FT_Odd_Under25
        jogo["FT_Odd_BTTS_Yes"] = FT_Odd_BTTS_Yes
        jogo["FT_Odd_BTTS_No"] = FT_Odd_BTTS_No

        try:
            jogo['Media_VG_H'] = df1[df1.Home == home]['Media_VG_H'].iloc[0]
            jogo['DP_VG_H'] = df1[df1.Home == home]['DP_VG_H'].iloc[0]
            jogo['CV_VG_H'] = df1[df1.Home == home]['CV_VG_H'].iloc[0]

            jogo['Media_CG_H'] = df1[df1.Home == home]['Media_CG_H'].iloc[0]
            jogo['DP_CG_H'] = df1[df1.Home == home]['DP_CG_H'].iloc[0]
            jogo['CV_CG_H'] = df1[df1.Home == home]['CV_CG_H'].iloc[0]

            jogo['Media_VG_A'] = df2[df2.Away == away]['Media_VG_A'].iloc[0]
            jogo['DP_VG_A'] = df2[df2.Away == away]['DP_VG_A'].iloc[0]
            jogo['CV_VG_A'] = df2[df2.Away == away]['CV_VG_A'].iloc[0]

            jogo['Media_CG_A'] = df2[df2.Away == away]['Media_CG_A'].iloc[0]
            jogo['DP_CG_A'] = df2[df2.Away == away]['DP_CG_A'].iloc[0]
            jogo['CV_CG_A'] = df2[df2.Away == away]['CV_CG_A'].iloc[0]
        except:
            pass

        lista.append(jogo)


df = pd.DataFrame(lista)
df.reset_index(inplace=True, drop=True)
df.index = df.index.set_names(['Nº'])
df = df.rename(index=lambda x: x + 1)
################################################################################
# Probabilidades
################################################################################
df['p_H'] = 1 / df.FT_Odd_H
df['p_D'] = 1 / df.FT_Odd_D
df['p_A'] = 1 / df.FT_Odd_A
df['p_Over'] = 1 / df.FT_Odd_Over25
df['p_Under'] = 1 / df.FT_Odd_Under25

################################################################################
# CV das Odds do Match Odds
################################################################################
df['CV_HDA'] = df[['p_H','p_D','p_A']].std(ddof=0, axis=1) / df[['p_H','p_D','p_A']].mean(axis=1)

# %% [markdown]
# # Utilizando o Modelo para Novos Dados

# %%
flt = df.League == 'ARGENTINA - LIGA PROFESIONAL'
df = df[flt]
df = drop_reset_index(df)
df

# %%
# Carregando o modelo salvo
saved_final_model = load_model('LAYAWAY_ARKAD_ARGENTINA - LIGA PROFESIONAL')

# Fazendo previsões com os novos dados
new_predictions = predict_model(saved_final_model, data=df)
print()
display(new_predictions)
